# %% [markdown]
# # <font color = Red> <center> ***🍔 McDonald's Nutritional Data Analysis 🍟***  </center>   </font>
# ### Sagar Goel

# %% [markdown]
# # <font color = purple> <center> ***Project Summary*** </center>  </font>
# This project involves an in-depth analysis of McDonald's menu items, focusing on their nutritional content. The dataset consists of 260 menu items, each belonging to one of 9 distinct food categories. The analysis centers on key nutrients such as **Calories, Protein, Carbohydrates, Sodium,** and **Dietary Fiber**, providing insights that can help both McDonald's customers and the organization.
#
# ### Key Objectives:
# 1. **Nutritional Profile**: Understand the nutritional distribution across various food categories by analyzing calories, macronutrients (Protein, Carbohydrates, Fat), and micronutrients (Sodium, Iron, Calcium, Vitamin A).
# 2. **Customer Insights**: Provide data-driven insights to help customers make informed food choices based on their dietary goals, such as selecting low-calorie or high-protein items.
# 3. **Menu Optimization**: Use the nutritional data to explore potential optimizations in portion sizes or new menu developments that align with current trends in health-conscious eating.
# 4. **Visualizing Trends**: Employ visualizations like histograms, bar charts, and box plots to uncover trends and patterns in nutrient distribution and identify outliers within the menu categories.
#
# ### Deliverables:
# - **Nutrient Distribution Analysis**: A breakdown of nutrient content by category and item.
# - **Nutritional Comparisons**: Compare items based on their calorie counts and macronutrient composition.
# - **Recommendations**: Highlight healthier options and suggest possible optimizations for the menu to enhance nutritional value.

# %% [markdown]
# ##### Git Hub Link - https://github.com/sagargoel93/McDonald-s-Menu-Nutritional-Analysis---Project

# %% [markdown]
# # 1. Data Collection

# %% [markdown]
#  ##### URL = "https://kh3-ls-storage.s3.us-east-1.amazonaws.com/Data%20Analyst%20Project/Nutrical%20Dataset.csv"

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.set(color_codes=True)

# %% [markdown]
# # 2. Data Preprocessing
# # 2.1 Load and inspect the dataset.

# %%
df = pd.read_csv(r'Nutrical Dataset.csv')

df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# # 2.2 Handle missing values and data cleaning if necessary.

# %%
df.isnull() .sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# Length: 260, dtype: bool

# %% [markdown]
# #

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 3.1 Analyzing distribution of calorie counts across menu items.
#
# In this section, we visualize the distribution of calorie counts across all menu items using a histogram with a Kernel Density Estimate (KDE). The histogram gives us an idea of how many items fall within specific calorie ranges, while the KDE provides a smoothed version of the distribution, highlighting the overall shape of the data.

# %%
df.groupby('Category').agg(Menu_Items_per_Category=('Category', 'count'),
                          Centerpoint_calories=('Calories', 'median'))
# Out:
#                     Menu_Items_per_Category  Centerpoint_calories
# Category
# Beef & Pork                              15                 500.0
# Beverages                                27                 100.0
# Breakfast                                42                 470.0
# Chicken & Fish                           27                 480.0
# Coffee & Tea                             95                 270.0
# Desserts                                  7                 250.0
# Salads                                    6                 255.0
# Smoothies & Shakes                       28                 540.0
# Snacks & Sides                           13                 260.0

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=20, kde=True, color='blue')
plt.title('Distribution of Calorie Counts across Menu Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Insights from the Histogram:
# - The majority of McDonald's menu items have calorie counts between 200 and 500 calories.
# - The distribution is right-skewed, with a long tail of higher-calorie items that extend beyond 1000 calories.
# - The Kernel Density Estimate (KDE) line reinforces this skewness and shows that there are fewer high-calorie items compared to lower-calorie options.
# - There is a noticeable drop in frequency after the 600-calorie mark, indicating that most items are designed to be within a moderate calorie range.

# %% [markdown]
# ### 3.2 Explore the nutritional content (e.g., fat, protein, carbohydrates) of different items.
#
# In this section, we will delve into the nutritional content of McDonald's menu items, specifically focusing on key macronutrients: fat, protein, and carbohydrates. Understanding these nutritional components is essential for evaluating the healthiness of menu options and making informed dietary choices.
#
# We will use various visualizations to illustrate the distribution and relationship of these nutritional values with calorie counts. By analyzing the nutritional content, we aim to identify trends, compare different menu categories, and highlight any notable insights regarding healthier options.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Total Fat', 'Protein', 'Carbohydrates']], palette="Set2")
plt.title('Distribution of Total Fat, Protein, and Carbohydrates')
plt.xlabel('Nutrient')
plt.ylabel('Nutritinol Values', fontsize=12)

plt.show()

# %%
df[['Total Fat','Protein','Carbohydrates']].describe()
# Out:
#         Total Fat     Protein  Carbohydrates
# count  260.000000  260.000000     260.000000
# mean    14.165385   13.338462      47.346154
# std     14.205998   11.426146      28.252232
# min      0.000000    0.000000       0.000000
# 25%      2.375000    4.000000      30.000000
# 50%     11.000000   12.000000      44.000000
# 75%     22.250000   19.000000      60.000000
# max    118.000000   87.000000     141.000000

# %% [markdown]
# ### Nutritional Content Analysis
#
# The box plot illustrates the distribution of total fat, protein, and carbohydrate content across McDonald's menu item:
#
#
# - Total Fat: The median fat content is around 20 grams. A few outliers have higher fat content above 60 grams.
# - Protein: The median protein content is slightly lower, around 20 grams, with some outliers reaching higher levels.
# - Carbohydrates: Carbohydrate content varies significantly, with the median around 60 grams, and several outliers exceed 100 grams.
#
# This visualization highlights the range of nutritional content across menu items, helping customers to make informed dietary choies requirementsments.

# %% [markdown]
# ### 3.3 Identify trends and patterns in the dataset.
#
# In this section, we aim to analyze the macronutrient composition of McDonald's menu items, specifically focusing on three major nutrien: Iron, Calcium and Vitamin A.
#
#
# This analysis will help us understand how these macronutrients are distributed across different menu items and their relation to one another. By visualizing these nutritional values, we can gain insights into how well-balanced the menu is in terms of its nutrient profile and identify potential outliers with unusually high or low val
#
# We will use barplot to represent the distribution of each macronutrient and their relationships to guide our observations.
# ions.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Iron (% Daily Value)', data=df, hue='Category')
plt.title('Total Iron by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Iron Distribution Analysis
# The bar chart shows that Beef & Pork has the highest iron content, followed by Breakfast and Chicken & Fish. Salads provide moderate iron, while Snacks & Sides, Desserts, and Smoothies & Shakes offer lower amounts. Beverages and Coffee & Tea contribute very little to iron intake. The bars indicate some variability within each category.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Calcium (% Daily Value)', data=df, hue='Category')
plt.title('Total Calcium by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Calcium Distribution Analysis
#
# The chart shows that Smoothies & Shakes have the highest calcium content, followed by Coffee & Tea. Beef & Pork, Breakfast, and Chicken & Fish provide moderate calcium, while Snacks & Sides and Beverages have the lowest levels.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Category', y='Vitamin A (% Daily Value)', data=df, hue='Category')
plt.title('Total Vitamin A by Food Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Vitamin A Distribution Analysis
# The chart shows that Salads have the highest vitamin A content, significantly exceeding other categories. Chicken & Fish and Smoothies & Shakes offer moderate amounts, while Beverages, Breakfast, Beef & Pork, and most other categories provide very low levels of vitamin A.s.

# %% [markdown]
# #

# %% [markdown]
# # 4. Data Visualization
#
# To better understand the calorie distribution and nutritional content of the menu items, I will create a series of data visualizations. First, I will generate a histogram and a box plot to explore the distribution of calorie counts across the menu. These plots will highlight the range of calorie values, reveal any outliers or skewness, and provide an overall view of the calorie distribution. Next, I will create bar charts comparing the nutritional characteristics—such as total fat, saturated fat, carbohydrates, and protein—across different food categories like burgers, salads, and desserts. These comparisons will help identify key differences in the nutrient profiles of these groups. Through these visualizations, we can gain a clearer understanding of the calorie and nutrient composition of the menu, aiding both consumer decision-making and menu development strategies.

# %% [markdown]
# #### 4.1 Distribution of Calories
# The histogram and boxplot for the said distribution can be plotted together with the help of a subplot, so that we can compare both the visuals side by side to get more comprehensive insights about the distribution as well as the outliers.

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['Calories'], bins=10, kde=True)
plt.title('Histogram of Calorie Distribution')
plt.xlabel('Calories')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Calories'])
plt.title('Box Plot of Calorie Distribution')
plt.xlabel('Calories')

plt.tight_layout()
plt.show()

# %% [markdown]
# The histogram reveals a right-skewed distribution, with a peak between 125 and 500 calories, and a long tail extending toward higher calorie values. Most menu items cluster on the lower end of the calorie spectrum, while only a few high-calorie outliers are present. The box plot supports this observation, showing a median calorie count of approximately 340 calories, with the 25th and 75th percentiles at 210 and 500 calories, respectively. The plot also highlights several outliers, particularly high-calorie items, beginning with the "McFlurry with Reese's Peanut Butter Cups (Medium)" at 810 calories.

# %% [markdown]
# #### Nutritional Content Comparison
#
# With the help of several bar-charts, histograms and boxplots we compare the nutritional characteristics of different food categories. As the count of nutrients is 22(which will not be as feasible), we create the visualizations for 4 selected list of nutrients namely,
# 1. Total Fat (% Daily Value)
# 2. Cholesterol (% Daily Value)
# 3. Sugars
# 4. Protein

# %%
plt.figure(figsize=(8, 15))  # Increase height for a better fit

# 1st Plot: Bar plot of Total Fat (% Daily Value) across Categories
plt.subplot(3, 1, 1)  # 3 rows, 1 column, this is the 1st plot
sns.barplot(data=df, x='Category', y='Total Fat (% Daily Value)', hue = 'Category' )
plt.title('Total Fat (% Daily Value) Distribution Across Categories')
plt.xlabel('Category')
plt.ylabel('Total Fat (% Daily Value)')
plt.xticks(rotation=90)

# 2nd Plot: Histogram for Total Fat (% Daily Value)
plt.subplot(3, 1, 2)  # 3 rows, 1 column, this is the 2nd plot
sns.histplot(df['Total Fat (% Daily Value)'], bins=15, kde=True)
plt.title('Total Fat (% Daily Value) Histogram')
plt.xlabel('Total Fat (% Daily Value)')
plt.ylabel('Frequency')

# 3rd Plot: Box plot for Total Fat (% Daily Value) across Categories
plt.subplot(3, 1, 3)  # 3 rows, 1 column, this is the 3rd plot
sns.boxplot(data=df, x='Category', y='Total Fat (% Daily Value)',hue = 'Category')
plt.title('Box Plot of Total Fat (% Daily Value) Distribution')
plt.xlabel('Category')
plt.ylabel('Total Fat (% Daily Value)')
plt.xticks(rotation=90)

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# ### Analysis of Total Fat (% Daily Value) Distribution
#
# 1. From the bar plot, we observe that the Breakfast category has the highest average Total Fat (% Daily Value) at approximately 43%, followed closely by the Chicken & Fish category at around 40%. In contrast, the Beverages category shows the lowest average Total Fat (% Daily Value), with negligible values.
#
# 2. From the histogram, the distribution of Total Fat (% Daily Value) is right-skewed, with the majority of items having lower fat values. The peak lies between 0 and 25%, showing that most menu items contain relatively low Total Fat (% Daily Value). However, there is a long tail extending towards higher fat values, indicating that a few items contain significantly higher Total Fat (% Daily Value).
#
# 3. From the box plot, focusing on the two categories with the highest average Total Fat (% Daily Value):
#
#       * Breakfast: The box plot reveals a relatively even distribution of Total Fat (% Daily Value) across breakfast items, with a median of 43%. The           25th percentile is around 30%, while the 75th percentile is 50%. Several outliers exist, indicating some breakfast items have significantly             higher fat content.
#
#       * Chicken & Fish: The distribution here is more skewed, with a median of approximately 40%. The 25th percentile lies around 28%, while the 75th           percentile is around 48%. Similar to breakfast, a few outliers reflect higher Total Fat (% Daily Value) values.

# %%
plt.figure(figsize=(8, 15))  

# 1st Plot: Bar plot of Cholesterol (% Daily Value) across Categories
plt.subplot(3, 1, 1)  # 3 rows, 1 column, this is the 1st plot
sns.barplot(data=df, x='Category', y='Cholesterol (% Daily Value)', hue = 'Category' )
plt.title('Cholesterol (% Daily Value) Distribution Across Categories')
plt.xlabel('Category')
plt.ylabel('Cholesterol (% Daily Value)')
plt.xticks(rotation=90)

# 2nd Plot: Histogram for Cholesterol (% Daily Value)
plt.subplot(3, 1, 2)  # 3 rows, 1 column, this is the 2nd plot
sns.histplot(df['Cholesterol (% Daily Value)'], bins=15, kde=True)
plt.title('Cholesterol (% Daily Value) Histogram')
plt.xlabel('Cholesterol (% Daily Value)')
plt.ylabel('Frequency')

# 3rd Plot: Box plot for Cholesterol (% Daily Value) across Categories
plt.subplot(3, 1, 3)  # 3 rows, 1 column, this is the 3rd plot
sns.boxplot(data=df, x='Category', y='Cholesterol (% Daily Value)', hue = 'Category')
plt.title('Box Plot of Cholesterol (% Daily Value) Distribution')
plt.xlabel('Category')
plt.ylabel('Cholesterol (% Daily Value)')
plt.xticks(rotation=90)

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# ### Analysis of Cholesterol (% Daily Value) Distribution:
#
# 1. From the Bar Plot: The Breakfast category has the highest average cholesterol content, approximately 50% of the daily value, followed by the Beef &     Pork category at around 30% and the Chicken & Fish category at approximately 25%. Notably, the Beverages category exhibits the lowest cholesterol       levels, with values that are almost negligible.
#
# 2. From the Histogram: The histogram shows a right-skewed distribution of cholesterol values, with a peak around 0 to 25%. Most items fall into this       lower cholesterol range, indicating that many menu items have relatively low cholesterol content. There is a gradual decline in frequency as            cholesterol levels increase, with only a few items reaching higher values beyond 75% of the daily value. The distribution suggests that while the       majority of items are low in cholesterol, there are outliers that significantly exceed this range.
#
# 3. From the Box Plot (Focusing on the Top Two Categories with Highest Average Cholesterol % Daily Value):
#
#     * Breakfast: The Breakfast category demonstrates a broader range of cholesterol values, with some items nearing 90% of the daily recommended value.       The median cholesterol level in this category is higher compared to others, highlighting its overall richness in cholesterol content.
#
#     * Beef & Pork: This category presents a more concentrated distribution, with most items clustered between 25% and 35% of the daily value.

# %%
plt.figure(figsize=(8, 15)) 

# 1st Plot: Bar plot of Sugars across Categories
plt.subplot(3, 1, 1)  # 3 rows, 1 column, this is the 1st plot
sns.barplot(data=df, x='Category', y='Sugars', hue='Category')
plt.title('Sugars Distribution Across Categories')
plt.xlabel('Category')
plt.ylabel('Sugars')
plt.xticks(rotation=90)

# 2nd Plot: Histogram for Sugars
plt.subplot(3, 1, 2)  # 3 rows, 1 column, this is the 2nd plot
sns.histplot(df['Sugars'], bins=15, kde=True)
plt.title('Sugars Histogram')
plt.xlabel('Sugars')
plt.ylabel('Frequency')

# 3rd Plot: Box plot for Sugars across Categories
plt.subplot(3, 1, 3)  # 3 rows, 1 column, this is the 3rd plot
sns.boxplot(data=df, x='Category', y='Sugars', hue='Category')
plt.title('Box Plot of Sugars')
plt.xlabel('Category')
plt.ylabel('Sugars')
plt.xticks(rotation=90)

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# ### Analysis of Sugars Distribution:
#
# 1. From the barplot:
#    - The Smoothies & Shakes category contains the highest average sugar content, with servings averaging around 80 grams of sugar.
#    - The Coffee & Tea category ranks second, with an average of approximately 40 grams of sugar per serving.
#    - The Snacks & Sides category has the lowest average sugar content, with around 8 grams per serving.
#
# 2. From the histogram:
#    - The histogram of sugar content reveals that most products contain less than 20 grams of sugar per serving, with the highest frequency occurring in the 0-10 gram range.
#    - A gradual decline in frequency can be observed as sugar content increases, with fewer products containing more than 60 grams of sugar.
#    - The data shows a long tail towards higher sugar levels, with some items reaching over 120 grams of sugar per serving, though these cases are much rarer.
#
# 3. From the boxplot (focusing on the top two categories with the highest average sugar content):
#    - The Smoothies & Shakes category exhibits the widest range in sugar content, with some products containing up to 100 grams of sugar per serving.
#    - The Coffee & Tea category also shows a considerable range in sugar content, with some items reaching as high as 60 grams of sugar per serving.
#    - Other than the Snacks & Sides category, which has the lowest sugar content, there are no significant outliers in sugar content across the categories.

# %%
plt.figure(figsize=(8, 15)) 

# 1st Plot: Bar plot of Protein across Categories
plt.subplot(3, 1, 1)  # 3 rows, 1 column, this is the 1st plot
sns.barplot(data=df, x='Category', y='Protein', hue='Category')
plt.title('Protein Distribution Across Categories')
plt.xlabel('Category')
plt.ylabel('Protein')
plt.xticks(rotation=90)

# 2nd Plot: Histogram for Protein
plt.subplot(3, 1, 2)  # 3 rows, 1 column, this is the 2nd plot
sns.histplot(df['Protein'], bins=15, kde=True)
plt.title('Protein Histogram')
plt.xlabel('Protein')
plt.ylabel('Frequency')

# 3rd Plot: Box plot for Protein across Categories
plt.subplot(3, 1, 3)  # 3 rows, 1 column, this is the 3rd plot
sns.boxplot(data=df, x='Category', y='Protein', hue='Category')
plt.title('Box Plot of Protein')
plt.xlabel('Category')
plt.ylabel('Protein')
plt.xticks(rotation=90)

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# ### Analysis of Protein Distribution:
#
# 1. From the barplot:
#    - The Chicken & Fish category contains the highest average protein content, with servings averaging around 29 grams of protein per serving.
#    - The Beef & Pork category ranks second, with an average of approximately 27 grams of protein per serving.
#    - The Beverages category has the lowest average protein content, with only around 2-3 grams of protein per serving.
#
# 2. From the histogram:
#    - The histogram of protein content reveals that most products contain less than 15 grams of protein per serving, with the highest frequency occurring in the 0-10 gram range.
#    - A clear decline in frequency is observed as protein content increases, with fewer products containing more than 20 grams of protein.
#    - There is a long tail in the distribution, showing some items with over 40 grams of protein, though these are rare occurrences, and a few items even reaching over 80 grams of protein.
#
# 3. From the boxplot (focusing on the top two categories with the highest average protein content):
#    - The Chicken & Fish category has the widest range in protein content, with some items containing up to 40 grams of protein per serving.
#    - The Beef & Pork category shows a slightly more compact distribution, with most items ranging between 22-37 grams of protein per serving.
#    - There are no substantial outliers in protein levels across the categories, but a few small outliers can be noted in the Chicken & Fish and Beverages categories, with a limited number of items showing spiked s.tein levels.
# in levels**.

# %% [markdown]
# ## 4.2 Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).

# %%
df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein','Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
'Calcium (% Daily Value)','Sodium', 'Iron (% Daily Value)']].median().plot(kind='bar',stacked=True,legend=False)
 
plt.title('Comparison of Calories and Nutritional Content Across Food Categories') 
plt.ylabel('Nutritional Values (per serving)') 
plt.xticks(rotation=45, ha='right') 
plt.legend(loc='center left', bbox_to_anchor=(1.04, 0.5), 
title='Nutritional Components', fontsize='small')  
plt.show()

print (' ')

df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein', 
                                  'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                                  'Calcium (% Daily Value)', 'Sodium', 'Iron (% Daily Value)']].median()
# Out:
#                     Calories  Carbohydrates  Dietary Fiber  Protein  \
# Category
# Beef & Pork            500.0           41.0            3.0     24.0
# Beverages              100.0           27.0            0.0      0.0
# Breakfast              470.0           45.0            3.0     19.0
# Chicken & Fish         480.0           44.0            3.0     27.0
# Coffee & Tea           270.0           45.0            1.0     10.0
# Desserts               250.0           32.0            1.0      2.0
# Salads                 255.0           21.0            4.5     24.0
# Smoothies & Shakes     540.0           88.0            1.0     12.0
# Snacks & Sides         260.0           30.0            1.0      6.0
#
#                     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# Category
# Beef & Pork                               6.0                        2.0
# Beverages                                 0.0                        0.0
# ...

# %%
df.groupby('Category')[['Total Fat', 'Cholesterol', 'Sugars']].median().plot(kind='bar',stacked=True,legend=False)


plt.title ('Total Fat,Sugar,Chlesterol level across Food Categories')
plt.ylabel('content')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='center left', bbox_to_anchor=(1.04, 0.5),
title='Nutritional Components', fontsize='small')
plt.show()

print (' ')

df.groupby('Category')[['Total Fat', 'Cholesterol', 'Sugars']].median()
# Out:
#                     Total Fat  Cholesterol  Sugars
# Category
# Beef & Pork              26.0         85.0     9.0
# Beverages                 0.0          0.0    27.0
# Breakfast                26.0         50.0     3.5
# Chicken & Fish           21.0         65.0     7.0
# Coffee & Tea              7.0         25.0    41.0
# Desserts                  8.0         10.0    15.0
# Salads                    8.0         60.0     5.5
# Smoothies & Shakes       16.0         52.5    74.5
# Snacks & Sides           11.0          5.0     2.0

# %% [markdown]
# #

# %% [markdown]
# ## 5. Nutrition-Based Insights
# ### 5.1 Identify menu items with the highest and lowest calorie counts.

# %%
# Top 5 highest calorie items
top_5_highest_calories = df[['Item', 'Calories']].sort_values(by='Calories', ascending=False).head(5).reset_index(drop=True)

print("Top 5 Highest Calorie Items:")
print(top_5_highest_calories)

print('-' * 65)

# Top 5 lowest calorie items
top_5_lowest_calories = df[['Item', 'Calories']].sort_values(by='Calories').head(5).reset_index(drop=True)

print("Top 5 Lowest Calorie Items:")
print(top_5_lowest_calories)
# Out:
# Top 5 Highest Calorie Items:
#                                                 Item  Calories
# 0                       Chicken McNuggets (40 piece)      1880
# 1        Big Breakfast with Hotcakes (Large Biscuit)      1150
# 2      Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 3  Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 4  Big Breakfast with Hotcakes and Egg Whites (Re...       990
# -----------------------------------------------------------------
# Top 5 Lowest Calorie Items:
#                      Item  Calories
# 0  Diet Dr Pepper (Child)         0
# 1       Iced Tea (Medium)         0
# 2        Iced Tea (Small)         0
# 3     Dasani Water Bottle         0
# 4          Coffee (Small)         0

# %% [markdown]
# ## 5.2 Determine the average nutritional content of popular menu categories.

# %%
df_avg_nutrients_all = df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein', 'Vitamin A (% Daily Value)', 
'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Sodium', 'Iron (% Daily Value)']].mean()

nutrient_to_plot = 'Calories'
data_to_plot = df_avg_nutrients_all[nutrient_to_plot]

plt.figure(figsize=(10, 8))
plt.pie(data_to_plot, labels=data_to_plot.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Average {nutrient_to_plot} Distribution Across Categories')
plt.axis('equal')  
plt.show()

# %%
df.groupby('Category')[['Calories', 'Carbohydrates', 'Dietary Fiber', 'Protein', 'Vitamin A (% Daily Value)', 
'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Sodium', 'Iron (% Daily Value)']].mean()
# Out:
#                       Calories  Carbohydrates  Dietary Fiber    Protein  \
# Category
# Beef & Pork         494.000000      40.133333       2.533333  27.333333
# Beverages           113.703704      28.814815       0.037037   1.333333
# Breakfast           526.666667      49.761905       3.261905  19.857143
# Chicken & Fish      552.962963      49.074074       2.925926  29.111111
# Coffee & Tea        283.894737      44.526316       0.778947   8.863158
# Desserts            222.142857      34.857143       1.000000   4.000000
# Salads              270.000000      21.666667       4.500000  19.833333
# Smoothies & Shakes  531.428571      90.428571       1.464286  10.857143
# Snacks & Sides      245.769231      29.153846       1.538462   8.384615
#
#                     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# Category
# Beef & Pork                          6.933333                   7.333333
# Beverages                            0.740741                  23.481481
# ...

# %% [markdown]
# #### The values displayed in the pie chart and table indicate which foods offer good nutritional content.
#
# Average Nutritional Content of Popular Menu Categories
#
# ##### Breakfast:
# The Breakfast category is extremely popular among McDonald's customers, providing a convenient option for a well-balanced meal that delivers essential nutrition to kickstart the day. A common choice is to pair breakfast items with Coffee & Tea, which many people enjoy to complement their meal.
#
# ##### Lunch:
# The Chicken & Fish category is favored by McDonald's patrons due to its comprehensive nutrient profile. This category is notably high in calories, carbohydrates, vitamins, and sodium, along with other nutritional elements. It’s advisable to consider this menu option alongside Salads and Smoothies & Shakes for a nutritious combination.
#
# ##### Dinner:
# The Beef & Pork category ranks as one of the most popular selections on McDonald's menu, featuring a range of nutrient-rich options such as burgers and wraps that help wrap up the day. Many diners enjoy pairing these meals with Beverages, Desserts, and Snacks & Sides, particularly at dinner. While these options offer a substantial amount of nutrients, the combination of fat, cholesterol, and sugar can be high, which may not be the best choice for those aiming to maintain a healthy diet.

# %% [markdown]
# #

# %% [markdown]
# # 6. Documentation and Reporting:

# %% [markdown]
# ## 6.1 Summarize the findings and insights from the analysis.

# %% [markdown]
# # McDonald's Nutritional Data Analysis
#
# This analysis focuses on the nutritional profile of 260 McDonald's menu items, divided into 9 categories. The dataset emphasizes five main nutrients: Calories, Protein, Carbohydrates, Sodium, and Dietary Fiber, while other nutrients and daily values are omitted for simplicity. The serving sizes are classified into weight-based and volume-based types.
#
# ## 1. Initial Data Understanding (Data Preprocessing)
# - **Loading and Inspection**: The dataset consists of 260 rows and 24 columns, providing information on key nutrients like Calories, Fat, Carbohydrates, and Protein, along with categorical fields like "Category" and "Item."
# - **Missing Values**: No missing values were detected, so no imputation was required.
# - **Data Cleaning**: All numerical data were properly formatted. However, the "Serving Size" column, stored as a string, may need further adjustments for analysis.
#
# ## 2. Nutrient Distribution Analysis
# - A histogram was generated to examine calorie distribution, revealing trends among the food items. Median values for Protein, Carbohydrates, and Total Fat were analyzed by category using a tabular approach.
# - Box plots were employed to visually highlight the statistical spread of Protein, Carbohydrates, and Fat within each category, providing insights into nutrient variation.
#
# ## 3. Trends and Patterns in Nutrient Data
# - To explore trends and outliers, horizontal bar plots with whisker lines were used, offering a clear view of the spread of key nutrients.
# - A detailed analysis was performed on three additional nutrients—Iron, Calcium, and Vitamin A—using both bar and box plots:
#   - **Iron**: Beef & Pork items had the highest average iron content, with Breakfast foods closely following.
#   - **Calcium**: Smoothies & Shakes had the highest calcium content, while Snacks & Sides and Breakfast items provided less.
#   - **Vitamin A**: The Salad category led in Vitamin A content, significantly higher than other categories.
#
# ## 4. Nutrient Distribution Comparison
# To compare nutrients across categories, a combination of bar charts, histograms, and box plots were used:
# - **Bar charts** illustrated nutrient content by category, offering insights to help customers
# - **Histograms** analyzed nutrient distributions Total Fat, Cholesterol, Sugars and Protein to showcase their ranges. showcase their ranges.
# - **Box plots** provided a statistical overview of nutrients, such as Calories and Sodium, helping to identify nutrient ranges across categories.
#
# ## 5. Stacked Bar Chart for Nutrient Comparison
# Stacked bar charts were created to visualize the distribution of key nutrients across categories, separating beneficial nutrients from those less beneficial. This representation, combined with tables, helped clarify nutrient-rich options, such as those high in Protein, Fiber, Vitamins, Calcium, and Iron.
#
# ## 6. Highest and Lowest Calorie Menu Items
# - **Highest Calories**: Chicken McNuggets (40 pieces) had the highest calorie content. For comparison, a typical daily calorie intake is around 1600-3200, depending on activity level.
# - **Lowest Calories**: Several items, such as Coffee, Diet Dr Pepper, and Dasani Water, contained 0 calories.
#
# ## 7. Average Nutritional Content of Popular Menu Categories
# To visualize the average nutrient content by category, a pie chart was created, highlighting the higher nutrient categories:
#
# - **Breakfast**: A popular choice for McDonald's customers, offering a well-rounded meal often paired with Coffee & Tea.
# - **Lunch**: The Chicken & Fish category is nutrient-rich, providing high levels of calories, carbohydrates, and sodium. Pairing with Salads or Smoothies can create a balanced meal.
# - **Dinner**: Beef & Pork items are a favorite for dinner, often accompanied by beverages or desserts. While nutrient-dense, these meals can also be high in fat, cholesterol, and sugar, which may not be ideal for a healthy diet.

# %% [markdown]
# ## 6.2 Explain how the nutritional analysis could benefit McDonald's customers and the organization.

# %% [markdown]
# ## Benefits of Nutritional Analysis for McDonald's Customers and the Organization
#
# ### For McDonald's Customers
# A detailed nutritional analysis provides several advantages to McDonald's customers:
#
# - **Informed Choices**: With access to nutritional data, customers can make smarter meal choices that align with their dietary needs, whether they’re aiming for low-calorie, high-protein, or well-balanced options.
# - **Healthier Eating Habits**: By identifying which food categories are rich in nutrients like Protein, Dietary Fiber, and Vitamins, customers can plan more nutritious meals, fostering better eating habits.
# - **Customization**: The analysis highlights menu items that may be high in fat, sodium, or sugar. This helps customers who need to limit these nutrients due to health conditions like hypertension or diabetes, allowing them to tailor their meals accordingly.
# - **Dietary Preferences**: Customers with specific dietary goals or restrictions can easily find suitable options. For example, high-protein items like Chicken & Fish or low-calorie beverages are helpful for those focused on weight management or muscle gain.
#
# ### For McDonald's Organization
# McDonald's can leverage this analysis to benefit both their customers and the business itself:
#
# - **Menu Optimization**: By understanding how nutrients are distributed across their offerings, McDonald's can refine their menu, adjusting portion sizes, ingredient combinations, or developing new items that cater to healthier preferences without sacrificing flavor.
# - **Targeted Marketing**: Nutritional insights can drive personalized marketing efforts. McDonald's can emphasize healthier choices like Salads, Smoothies & Shakes, or low-calorie drinks to attract health-conscious customers, enhancing targeted promotions for different consumer groups.
# - **Improved Customer Loyalty**: Transparency around nutrition builds trust and fosters a stronger connection with customers. Providing clear, accessible nutritional information helps McDonald's build long-term loyalty, especially among those prioritizing healthy eating.
# - **Regulatory Compliance**: Many regions require restaurants to provide detailed nutritional information. This analysis ensures McDonald's remains compliant with these regulations, avoiding legal issues and demonstrating their commitment to transparency.
# - **New Product Development**: Nutritional insights can guide the development of healthier menu items that appeal to a wider audience, including individuals who previously avoided fast food due to health concerns.
#
# In summary, nutritional analysis benefits both McDonald's and its customers by promoting informed decisions and healthier options while offering opportunities for menu innovation, customer engagement, and regulatory compliance.
